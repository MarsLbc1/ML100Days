# %% [markdown]
# 作業目標:<br>
# 1.讀取各種檔案格式<br>
# 2.輸出各種檔案格式<br>

# %% [markdown]
# 作業重點:<br>
# 1.不同檔案讀取方式皆不同，須了解檔案格式中的邏輯，例如:csv是以逗號分隔<br>
# 2.讀取、輸出檔案的程式碼不同，須注意使用方式

# %% [markdown]
# 題目: <br>
# 讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案

# %%
import pandas as pd

# %%
# !pip install openpyxl
# !pip install XLRD

# %%
#讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案
boston_data = pd.read_csv("D:/Codes/boston.csv")
boston_data
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO       B  LSTAT
# ...

# %%
Boston_data = pd.read_csv("D:/Codes/boston.csv",header=0,usecols=['CHAS','NOX','RM'])
Boston_data
# Out:
#      CHAS    NOX     RM
# 0     0.0  0.538  6.575
# 1     0.0  0.469  6.421
# 2     0.0  0.469  7.185
# 3     0.0  0.458  6.998
# 4     0.0  0.458  7.147
# ..    ...    ...    ...
# 501   0.0  0.573  6.593
# 502   0.0  0.573  6.120
# 503   0.0  0.573  6.976
# 504   0.0  0.573  6.794
# 505   0.0  0.573  6.030
#
# [506 rows x 3 columns]

# %%
Boston_data.to_excel("D:/Codes/my_boston.xlsx",sheet_name='boston')

# %%
boston_data1 = pd.read_excel("D:/Codes/my_boston.xlsx")
boston_data1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-3c89a13ccfff> in <module>
# ----> 1 boston_data1 = pd.read_excel("D:/Codes/my_boston.xlsx")
#       2 boston_data1
#
# D:\Python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# D:\Python\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# ...
